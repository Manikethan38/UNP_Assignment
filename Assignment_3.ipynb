# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikethan38/UNP_Assignment/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Generate 10000 values between 5 and 500. Find its mean, median, variance, 25th percentile.

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("dat.csv",index_col=0)
arr=np.random.randint(5,500,10000)
print(arr)
print(np.mean(arr))
print(np.median(arr))
print(np.percentile(arr,25))
data
# Out:
# [195  62 486 ... 308 121 155]
# 255.4553
# 257.0
# 134.0
#              class  Gender   Age  Survived
# PassengerId
# 1              3.0    male  22.0       0.0
# 2              1.0  female  38.0       1.0
# 3              3.0  female  26.0       1.0
# 4              NaN  female  35.0       NaN
# 5              3.0    male  35.0       0.0
# 6              3.0    male   NaN       0.0
# 7              1.0    male  54.0       0.0
# 8              3.0    male   2.0       0.0
# 9              3.0     NaN  27.0       1.0
# 10             2.0  female  14.0       1.0
# 11             3.0  female   4.0       1.0
# 12             1.0  female  58.0       1.0
# 13             3.0    male  20.0       0.0
# 14             NaN    male  39.0       NaN
# 15             3.0  female  14.0       0.0
# 16             2.0  female  55.0       1.0
# 17             3.0    male   2.0       0.0
# 18             2.0    male   NaN       1.0

# %% [markdown]
# 2.In the “dat.csv” replace all the null values with the mean of their respective columns (except Gender).

# %%
data=pd.read_csv("dat.csv",index_col=0)
data.isna()# gives boolean value to check the cell is empty or not
data["class"].fillna(np.mean(data["class"]),inplace=True)
data["Age"].fillna(np.mean(data["Age"]),inplace=True)
data["Survived"].fillna(np.mean(data["Survived"]),inplace=True)
data
# Out:
#               class  Gender      Age  Survived
# PassengerId
# 1            3.0000    male  22.0000       0.0
# 2            1.0000  female  38.0000       1.0
# 3            3.0000  female  26.0000       1.0
# 4            2.4375  female  35.0000       0.5
# 5            3.0000    male  35.0000       0.0
# 6            3.0000    male  27.8125       0.0
# 7            1.0000    male  54.0000       0.0
# 8            3.0000    male   2.0000       0.0
# 9            3.0000     NaN  27.0000       1.0
# 10           2.0000  female  14.0000       1.0
# 11           3.0000  female   4.0000       1.0
# 12           1.0000  female  58.0000       1.0
# 13           3.0000    male  20.0000       0.0
# 14           2.4375    male  39.0000       0.5
# 15           3.0000  female  14.0000       0.0
# 16           2.0000  female  55.0000       1.0
# 17           3.0000    male   2.0000       0.0
# 18           2.0000    male  27.8125       1.0

# %% [markdown]
# 3.Create a new column called “Bool” which has value as “yes” if Survived=0 and “no” if Survived=1.

# %%
data['Bool'] = np.where(data['Survived']== 1, True, False)
data
# Out:
#              class  Gender   Age  Survived   Bool
# PassengerId
# 1              3.0    male  22.0       0.0  False
# 2              1.0  female  38.0       1.0   True
# 3              3.0  female  26.0       1.0   True
# 4              NaN  female  35.0       NaN  False
# 5              3.0    male  35.0       0.0  False
# 6              3.0    male   NaN       0.0  False
# 7              1.0    male  54.0       0.0  False
# 8              3.0    male   2.0       0.0  False
# 9              3.0     NaN  27.0       1.0   True
# 10             2.0  female  14.0       1.0   True
# 11             3.0  female   4.0       1.0   True
# 12             1.0  female  58.0       1.0   True
# 13             3.0    male  20.0       0.0  False
# 14             NaN    male  39.0       NaN  False
# 15             3.0  female  14.0       0.0  False
# 16             2.0  female  55.0       1.0   True
# 17             3.0    male   2.0       0.0  False
# ...

# %% [markdown]
# 4.What is the mean age of the data?

# %%
np.mean(data['Age'])
# Out:
# 27.8125

# %% [markdown]
# 5.Rename the “PassengerId” column name to “Id”

# %%
 data.rename(columns={'PassengerId':'Id'}, inplace=True)
data
# Out:
#              class  Gender   Age  Survived   Bool
# PassengerId
# 1              3.0    male  22.0       0.0  False
# 2              1.0  female  38.0       1.0   True
# 3              3.0  female  26.0       1.0   True
# 4              NaN  female  35.0       NaN  False
# 5              3.0    male  35.0       0.0  False
# 6              3.0    male   NaN       0.0  False
# 7              1.0    male  54.0       0.0  False
# 8              3.0    male   2.0       0.0  False
# 9              3.0     NaN  27.0       1.0   True
# 10             2.0  female  14.0       1.0   True
# 11             3.0  female   4.0       1.0   True
# 12             1.0  female  58.0       1.0   True
# 13             3.0    male  20.0       0.0  False
# 14             NaN    male  39.0       NaN  False
# 15             3.0  female  14.0       0.0  False
# 16             2.0  female  55.0       1.0   True
# 17             3.0    male   2.0       0.0  False
# ...

# %% [markdown]
# 6.How many male and female people are there in our data?

# %%
data['Gender'].value_counts()
# Out:
# male      9
# female    8
# Name: Gender, dtype: int64
